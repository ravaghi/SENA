# %% [markdown]
# ### Hyperparameters

# %%
EPOCHS = 20
BATCH_SIZE = 64

EMBEDDING_DIM = 100
LSTM_UNITS = 32

# %% [markdown]
# ### Loading data

# %%
from data.norec.dataloader import load_full_dataset
from data.dataloader import load_data

dataset = load_full_dataset()
data = load_data(dataset)
# Out:
# Cleaning text...
# Fitting tokenizer...
# Converting texts to sequences...
# Padding sequences...
# One-hot encoding labels...
# Done!

# %% [markdown]
# # Classifying with multiclass dataset

# %%
X_train = data['X_train']
X_val = data['X_val']
X_test = data['X_test']
y_train = data['y_train']
y_val = data['y_val']
y_test = data['y_test']
num_words = data['num_words']
maxlen = data['maxlen']
num_classes = data['num_classes']
tokenizer = data['tokenizer']

print('X_train shape:', X_train.shape)
print('X_val shape:', X_val.shape)
print('X_test shape:', X_test.shape)
print('y_train shape:', y_train.shape)
print('y_val shape:', y_val.shape)
print('y_test shape:', y_test.shape)
print('num_words:', num_words)
print('maxlen:', maxlen)
print('num_classes:', num_classes)
# Out:
# X_train shape: (34903, 219)
# X_val shape: (4360, 219)
# X_test shape: (4351, 219)
# y_train shape: (34903, 3)
# y_val shape: (4360, 3)
# y_test shape: (4351, 3)
# num_words: 20000
# maxlen: 219
# num_classes: 3

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding

model = Sequential()
model.add(Embedding(num_words, EMBEDDING_DIM, input_length=maxlen))
model.add(LSTM(LSTM_UNITS))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 219, 100)          2000000
#
#  lstm (LSTM)                 (None, 32)                17024
#
#  dense (Dense)               (None, 3)                 99
#
# =================================================================
# Total params: 2,017,123
# Trainable params: 2,017,123
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE,
                    validation_data=(X_val, y_val), verbose=1)
# Out:
# Epoch 1/20
# 546/546 [==============================] - 30s 49ms/step - loss: 0.6124 - accuracy: 0.7640 - val_loss: 0.4787 - val_accuracy: 0.7995
# Epoch 2/20
# 546/546 [==============================] - 23s 41ms/step - loss: 0.4092 - accuracy: 0.8349 - val_loss: 0.5356 - val_accuracy: 0.8067
# Epoch 3/20
# 546/546 [==============================] - 23s 42ms/step - loss: 0.2816 - accuracy: 0.8922 - val_loss: 0.5606 - val_accuracy: 0.7755
# Epoch 4/20
# 546/546 [==============================] - 23s 43ms/step - loss: 0.1860 - accuracy: 0.9337 - val_loss: 0.6947 - val_accuracy: 0.7670
# Epoch 5/20
# 546/546 [==============================] - 27s 50ms/step - loss: 0.1220 - accuracy: 0.9597 - val_loss: 0.7978 - val_accuracy: 0.7823
# Epoch 6/20
# 546/546 [==============================] - 38s 70ms/step - loss: 0.0772 - accuracy: 0.9758 - val_loss: 0.9872 - val_accuracy: 0.7649
# Epoch 7/20
# 546/546 [==============================] - 38s 69ms/step - loss: 0.0637 - accuracy: 0.9802 - val_loss: 1.1270 - val_accuracy: 0.7883
# Epoch 8/20
# 546/546 [==============================] - 35s 64ms/step - loss: 0.0432 - accuracy: 0.9873 - val_loss: 1.1385 - val_accuracy: 0.7773
# Epoch 9/20
# 546/546 [==============================] - 35s 64ms/step - loss: 0.0297 - accuracy: 0.9909 - val_loss: 1.2278 - val_accuracy: 0.7752
# Epoch 10/20
# 546/546 [==============================] - 37s 68ms/step - loss: 0.0268 - accuracy: 0.9919 - val_loss: 1.2570 - val_accuracy: 0.7867
# Epoch 11/20
# 546/546 [==============================] - 35s 64ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 1.3099 - val_accuracy: 0.7766
# Epoch 12/20
# 546/546 [==============================] - 34s 63ms/step - loss: 0.0439 - accuracy: 0.9858 - val_loss: 1.2866 - val_accuracy: 0.7869
# Epoch 13/20
# 546/546 [==============================] - 30s 54ms/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 1.4426 - val_accuracy: 0.7764
# Epoch 14/20
# 546/546 [==============================] - 31s 57ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 1.4258 - val_accuracy: 0.7757
# Epoch 15/20
# 546/546 [==============================] - 30s 54ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 1.5308 - val_accuracy: 0.7674
# Epoch 16/20
# 546/546 [==============================] - 30s 55ms/step - loss: 0.0233 - accuracy: 0.9936 - val_loss: 1.4049 - val_accuracy: 0.7835
# Epoch 17/20
# 546/546 [==============================] - 30s 54ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 1.5594 - val_accuracy: 0.7810
# Epoch 18/20
# 546/546 [==============================] - 30s 54ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 1.5496 - val_accuracy: 0.7608
# Epoch 19/20
# 546/546 [==============================] - 29s 53ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 1.5340 - val_accuracy: 0.7805
# Epoch 20/20
# 546/546 [==============================] - 31s 57ms/step - loss: 0.0173 - accuracy: 0.9951 - val_loss: 1.4293 - val_accuracy: 0.7821

# %%
val_loss, val_acc = model.evaluate(X_test, y_test, verbose=1)
print("Validation loss:", val_loss)
print("Validation accuracy:", val_acc)
# Out:
# 136/136 [==============================] - 3s 21ms/step - loss: 1.4161 - accuracy: 0.7745
# Validation loss: 1.4161088466644287
# Validation accuracy: 0.7745345830917358

# %%
from utils.visualization import plot_history

plot_history(history, plot_name="base_model", save=True, show=True)
